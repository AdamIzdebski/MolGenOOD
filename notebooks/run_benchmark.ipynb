# %%
# imports
     
from scripts.plot_benchmark_results import plot_benchmark_results
from scripts.run_benchmark import main as run_benchmark


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# constants

DATA_DIR = "data/processed/zinc250k_synthetic_threshold_90_n_3000/logp"
OUT_DIR = "results/synthetic_threshold_90_n_3000/logp"

# %% [markdown]
# ## kNN

# %%
results = run_benchmark(
    data_dir=DATA_DIR,
    out_dir=OUT_DIR,
    probe_name="knn",
)
# Out:
# ----------------------------------------------------------------------------------------------------
# Random state: 0
# ----------------------------------------------------------------------------------------------------
# Train size: 2400 with class balance: 0.2125
# IID size: 159 with class balance: 0.16981132075471697
# OOD size: 441 with class balance: 0.20408163265306123
# Synthetic size: 600 with class balance: 0.1
# ...
# KNN probe hyperparameter search: 100%|█████████████████████████████████████| 18/18 [00:22<00:00,  1.28s/model]
# /home/adamizdebski/Y/envs/mol-gen-ood/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:2462: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# /home/adamizdebski/Y/envs/mol-gen-ood/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:2462: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# ...

# %%
plot_benchmark_results(
    results=results,
    title="kNN probe on Random split",
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 plot_benchmark_results(
#       2     results=results,
#       3     title="kNN probe on Random split",
#       4 )
#
# File <string>:48, in plot_benchmark_results(results, title, figsize, dpi, show)
#
# IndexError: list index out of range

# %% [markdown]
# ## RF

# %%
results = run_benchmark(
    data_dir=DATA_DIR,
    out_dir=OUT_DIR,
    probe_name="rf",
)
# Out:
# ----------------------------------------------------------------------------------------------------
# Random state: 0
# ----------------------------------------------------------------------------------------------------
# Train size: 2400 with class balance: 0.2125
# IID size: 159 with class balance: 0.16981132075471697
# OOD size: 441 with class balance: 0.20408163265306123
# Synthetic size: 600 with class balance: 0.1
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
#
# Best hyperparameters: {'class_weight': 'balanced', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200}
# Best CV auprc: 0.5786
# --- Results (IID) ---
# Automatically selected threshold: 0.566
# AUPRC (IID): 0.36176590794713204
# Mean similarity to train (IID): 0.4604866406690635
# --- Results (OOD) ---
# Automatically selected threshold: 0.549
# AUPRC (OOD): 0.5853524660547257
# Mean similarity to train (OOD): 0.3233798036252897
# --- Results (Synthetic) ---
# ...

# %%
plot_benchmark_results(
    results=results,
    title="RF probe on Random split",
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 plot_benchmark_results(
#       2     results=results,
#       3     title="RF probe on Random split",
#       4 )
#
# File <string>:48, in plot_benchmark_results(results, title, figsize, dpi, show)
#
# IndexError: list index out of range
